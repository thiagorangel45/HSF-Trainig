# %%
import ROOT
import numpy as np

# %%
#--------------------------------
# simulate some data
#--------------------------------
background_data = np.random.gamma(shape=2.2, scale=20, size=90000)
signal_data = np.random.normal(loc=100, scale=12, size=10000)
data_values = np.concatenate((signal_data, background_data))

# %%
#--------------------------------
# make model
#-------------------------------
# this is the distribution we'll be looking at
mass = ROOT.RooRealVar("mass", "mass", 0, 200)

# %%
# background variables
gamma = ROOT.RooRealVar("gamma", "gamma", 1, 0, 1e6)
beta = ROOT.RooRealVar("beta", "beta",    1, 0, 1e6)
mu = ROOT.RooRealVar("mu", "mu",          0, 0, 0) # fix this at 0

# signal variables
# we want to find a particle in the 60 --> 140 GeV range
mean = ROOT.RooRealVar("mean", "mean",    80, 60, 140)
sigma = ROOT.RooRealVar("sigma", "sigma", 1, 0, 40)

# %%
# what fraction is signal
# initial guess = half
fsig = ROOT.RooRealVar("fsig", "fsig", 0.5, 0, 1)

# background
sig = ROOT.RooGaussian("sig", "sig",
                       mass, mean, sigma)
# background
bkg = ROOT.RooGamma("bkg", "bkg",
                    mass, gamma, beta, mu)

# total model is the sum of those
model = ROOT.RooAddPdf("model", "model",
                       ROOT.RooArgList(sig, bkg), fsig)
# Out:
# [#0] WARNING:InputArguments -- The parameter 'sigma' with range [0, 40] of the RooGaussian 'sig' exceeds the safe range of (0, inf). Advise to limit its range.
# [#0] WARNING:InputArguments -- The parameter 'gamma' with range [0, 1e+06] of the RooGamma 'bkg' exceeds the safe range of (0, inf). Advise to limit its range.
# [#0] WARNING:InputArguments -- The parameter 'beta' with range [0, 1e+06] of the RooGamma 'bkg' exceeds the safe range of (0, inf). Advise to limit its range.

# %%
#------------------------------
# fit model to data
#------------------------------
data = ROOT.RooDataSet.from_numpy({'mass': data_values}, [mass])
model.fitTo(data)

# print values
print(mean)
print(sigma)
print(gamma)
print(beta)
print(mu)
print(fsig)
# Out:
# RooRealVar::mean = 99.8946 +/- 0.224619  L(60 - 140)
#
# RooRealVar::sigma = 11.9429 +/- 0.215895  L(0 - 40)
#
# RooRealVar::gamma = 2.19386 +/- 0.0105168  L(0 - 1e+06)
#
# RooRealVar::beta = 20.018 +/- 0.131161  L(0 - 1e+06)
#
# RooRealVar::mu = 0 +/- 0  L(0 - 0)
#
# RooRealVar::fsig = 0.10011 +/- 0.0020729  L(0 - 1)
#
# [#0] WARNING:DataHandling -- RooDataSet.from_numpy() Ignored 73 out-of-range events
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig,bkg)
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::optimizeConstantTerms: set of constant parameters changed, rerunning const optimizer
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (sig,bkg)
# Minuit2Minimizer: Minimize with max-calls 3000 convergence for edm < 1 strategy 1
# Minuit2Minimizer : Valid minimum - status = 0
# FVAL  = 474249.979154882545
# Edm   = 2.28025813282210409e-05
# Nfcn  = 810
# beta	  = 20.018	 +/-  0.131416	(limited)
# fsig	  = 0.10011	 +/-  0.00208415	(limited)
# gamma	  = 2.19386	 +/-  0.0105272	(limited)
# mean	  = 99.8946	 +/-  0.225014	(limited)
# mu	  = 0	 (const)
# sigma	  = 11.9429	 +/-  0.217064	(limited)
# Number of free parameters from FitConfig = 6
# Number of free parameters from Minimizer = 5
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# Info in <Minuit2>: Minuit2Minimizer::SetVariable Parameter mu has zero or invalid step size - consider it as constant
# Info in <Minuit2>: MnSeedGenerator Computing seed using NumericalGradient calculator
# Info in <Minuit2>: MnSeedGenerator Initial state: FCN =       4342042.368 Edm =      -947354.6675 NCalls =     23
# Info in <Minuit2>: NegativeG2LineSearch Doing a NegativeG2LineSearch since one of the G2 component is negative
# Info in <Minuit2>: MnSeedGenerator Negative G2 found - new state:
#   Minimum value : 1313081.138
#   Edm           : 2365400.597
#   Internal parameters:	[     -1.568796326                0     -1.559008097     0.0954164193     -1.253235898]
#   Internal gradient  :	[     -947748735.8      84932.83865     -15133344.69      13444.79874     -976015.7049]
#   Internal covariance matrix:
# [[  4.7607542e-13              0              0              0              0]
#  [              0  2.0090225e-05              0              0              0]
#  [              0              0   2.257502e-11              0              0]
#  [              0              0              0  9.3954873e-07              0]
#  [              0              0              0              0  9.3256915e-06]]]
# Info in <Minuit2>: MnSeedGenerator Initial state
#   Minimum value : 1313081.138
#   Edm           : 2365400.597
#   Internal parameters:	[     -1.568796326                0     -1.559008097     0.0954164193     -1.253235898]
#   Internal gradient  :	[     -947748735.8      84932.83865     -15133344.69      13444.79874     -976015.7049]
#   Internal covariance matrix:
# [[  4.7607542e-13              0              0              0              0]
#  [              0  2.0090225e-05              0              0              0]
#  [              0              0   2.257502e-11              0              0]
#  [              0              0              0  9.3954873e-07              0]
#  [              0              0              0              0  9.3256915e-06]]]
# Info in <Minuit2>: VariableMetricBuilder Start iterating until Edm is < 0.001 with call limit = 3000
# Info in <Minuit2>: VariableMetricBuilder    0 - FCN =       1313081.138 Edm =       2365400.597 NCalls =     70
# Info in <Minuit2>: VariableMetricBuilder    1 - FCN =       578127.7187 Edm =       24706.80536 NCalls =     91
# Info in <Minuit2>: VariableMetricBuilder    2 - FCN =       544872.5496 Edm =       2761.287262 NCalls =    108
# Info in <Minuit2>: VariableMetricBuilder    3 - FCN =       496789.5742 Edm =       2039.095838 NCalls =    130
# Info in <Minuit2>: VariableMetricBuilder    4 - FCN =       492662.1162 Edm =       702.0315679 NCalls =    144
# Info in <Minuit2>: VariableMetricBuilder    5 - FCN =       490171.0741 Edm =       267.2683841 NCalls =    162
# Info in <Minuit2>: VariableMetricBuilder    6 - FCN =       489298.7873 Edm =       400.8479739 NCalls =    174
# Info in <Minuit2>: VariableMetricBuilder    7 - FCN =       485504.6524 Edm =       1505.124324 NCalls =    193
# Info in <Minuit2>: VariableMetricBuilder    8 - FCN =        482786.496 Edm =       17.23821953 NCalls =    210
# Info in <Minuit2>: VariableMetricBuilder    9 - FCN =       482764.1714 Edm =       16.90969563 NCalls =    222
# Info in <Minuit2>: VariableMetricBuilder   10 - FCN =       482749.9715 Edm =       2.674181897 NCalls =    234
# Info in <Minuit2>: VariableMetricBuilder   11 - FCN =       482585.2703 Edm =       116.3688059 NCalls =    252
# Info in <Minuit2>: VariableMetricBuilder   12 - FCN =       482374.5565 Edm =       253.6434305 NCalls =    267
# Info in <Minuit2>: VariableMetricBuilder   13 - FCN =         482135.62 Edm =       30.03417143 NCalls =    279
# Info in <Minuit2>: VariableMetricBuilder   14 - FCN =       482100.1793 Edm =       5.452583431 NCalls =    291
# Info in <Minuit2>: VariableMetricBuilder   15 - FCN =       482091.8948 Edm =       5.585514585 NCalls =    303
# Info in <Minuit2>: VariableMetricBuilder   16 - FCN =       481983.1642 Edm =       96.15966215 NCalls =    317
# Info in <Minuit2>: VariableMetricBuilder   17 - FCN =       480364.1783 Edm =        764.209794 NCalls =    335
# Info in <Minuit2>: VariableMetricBuilder   18 - FCN =       478444.1088 Edm =       3873.353147 NCalls =    350
# Info in <Minuit2>: VariableMetricBuilder   19 - FCN =       477236.1538 Edm =       780.8731346 NCalls =    362
# Info in <Minuit2>: VariableMetricBuilder   20 - FCN =       476275.8838 Edm =       281.5021236 NCalls =    380
# Info in <Minuit2>: VariableMetricBuilder   21 - FCN =       475805.1727 Edm =       711.9205113 NCalls =    397
# Info in <Minuit2>: VariableMetricBuilder   22 - FCN =       475476.4711 Edm =       24.43298524 NCalls =    413
# Info in <Minuit2>: VariableMetricBuilder   23 - FCN =       475443.0522 Edm =        4.71851755 NCalls =    427
# Info in <Minuit2>: VariableMetricBuilder   24 - FCN =       475419.8548 Edm =        12.8172399 NCalls =    441
# Info in <Minuit2>: VariableMetricBuilder   25 - FCN =       475396.5976 Edm =       11.16179519 NCalls =    457
# Info in <Minuit2>: VariableMetricBuilder   26 - FCN =       475388.0064 Edm =       0.312824487 NCalls =    471
# Info in <Minuit2>: VariableMetricBuilder   27 - FCN =       475387.6202 Edm =     0.05198168717 NCalls =    483
# Info in <Minuit2>: VariableMetricBuilder   28 - FCN =       475387.3036 Edm =      0.2169578066 NCalls =    496
# Info in <Minuit2>: VariableMetricBuilder   29 - FCN =       475380.9721 Edm =       6.523838099 NCalls =    514
# Info in <Minuit2>: VariableMetricBuilder   30 - FCN =       475380.7596 Edm =        1.04222689 NCalls =    527
# Info in <Minuit2>: VariableMetricBuilder   31 - FCN =        475357.612 Edm =       16.36020449 NCalls =    545
# Info in <Minuit2>: VariableMetricBuilder   32 - FCN =        475326.257 Edm =       74.10018782 NCalls =    559
# Info in <Minuit2>: VariableMetricBuilder   33 - FCN =       475309.1447 Edm =       30.53658932 NCalls =    572
# Info in <Minuit2>: VariableMetricBuilder   34 - FCN =       475290.2059 Edm =       26.04561488 NCalls =    585
# Info in <Minuit2>: VariableMetricBuilder   35 - FCN =       475238.0649 Edm =       61.85976566 NCalls =    598
# Info in <Minuit2>: VariableMetricBuilder   36 - FCN =       475201.3049 Edm =       76.00809172 NCalls =    611
# Info in <Minuit2>: VariableMetricBuilder   37 - FCN =       475142.5654 Edm =       93.58485194 NCalls =    626
# Info in <Minuit2>: VariableMetricBuilder   38 - FCN =       475132.3539 Edm =       26.71282461 NCalls =    639
# Info in <Minuit2>: VariableMetricBuilder   39 - FCN =       475035.8533 Edm =       505.1096561 NCalls =    652
# Info in <Minuit2>: VariableMetricBuilder   40 - FCN =       475022.2278 Edm =       13.17086083 NCalls =    664
# Info in <Minuit2>: VariableMetricBuilder   41 - FCN =       474929.9762 Edm =       117.5908093 NCalls =    680
# Info in <Minuit2>: VariableMetricBuilder   42 - FCN =       474856.4331 Edm =       235.2640006 NCalls =    694
# Info in <Minuit2>: VariableMetricBuilder   43 - FCN =       474718.0723 Edm =       211.5440638 NCalls =    711
# Info in <Minuit2>: VariableMetricBuilder   44 - FCN =       474297.1362 Edm =       32.88541406 NCalls =    726
# Info in <Minuit2>: VariableMetricBuilder   45 - FCN =       474250.5103 Edm =      0.6572456423 NCalls =    738
# Info in <Minuit2>: VariableMetricBuilder   46 - FCN =       474250.0482 Edm =       0.107829872 NCalls =    750
# Info in <Minuit2>: VariableMetricBuilder   47 - FCN =       474249.9817 Edm =    0.002678238864 NCalls =    762
# Info in <Minuit2>: VariableMetricBuilder   48 - FCN =       474249.9792 Edm =   1.801211934e-05 NCalls =    773
# Info in <Minuit2>: VariableMetricBuilder After Hessian
# Info in <Minuit2>: VariableMetricBuilder   49 - FCN =       474249.9792 Edm =   2.280258133e-05 NCalls =    810
# Error in <ROOT::Math::FitResult>: FitConfiguration and Minimizer result are not consistent
# Info in <Minuit2>: Minuit2Minimizer::Hesse Using max-calls 3000
# Info in <Minuit2>: Minuit2Minimizer::Hesse Hesse is valid - matrix is accurate

# %%
#-------------------------------
# plot results
#-------------------------------
hist_data = ROOT.TH1F("data_hist", "", 50, 0, 200)
for v in data_values:
    hist_data.Fill(v)

# plot bkg only, sig only, and combo
bkg_only_graph = ROOT.TGraph()
sig_only_graph = ROOT.TGraph()
model_graph =    ROOT.TGraph()

for v in np.linspace(0, 200, 1000):
    mass.setVal(v)
    n = bkg_only_graph.GetN()
    
    bkg_only_graph.SetPoint(n, v, bkg.getVal(mass))
    sig_only_graph.SetPoint(n, v, sig.getVal(mass))
    model_graph.SetPoint(   n, v, model.getVal(mass))


bkg_only_graph.Scale(hist_data.GetBinWidth(1)*len(data_values)*(1.0-fsig.getVal()))
sig_only_graph.Scale(hist_data.GetBinWidth(1)*len(data_values)*fsig.getVal())
model_graph.Scale(hist_data.GetBinWidth(1)*len(data_values))


leg = ROOT.TLegend(0.6, 0.6, 0.88, 0.88)
leg.AddEntry(hist_data, "Data", "lep")
leg.AddEntry(bkg_only_graph, "Background only", "l")
leg.AddEntry(sig_only_graph, "Signal only", "l")
leg.AddEntry(model_graph, "Combined model", "l")


hist_data.GetXaxis().SetTitle("Mass [GeV]")
hist_data.GetYaxis().SetTitle("Events / 4 GeV")
hist_data.SetStats(0)
hist_data.SetLineWidth(2)

bkg_only_graph.SetLineColor(ROOT.kRed)
sig_only_graph.SetLineColor(ROOT.kMagenta)
model_graph.SetLineColor(ROOT.kBlack)


c = ROOT.TCanvas()
hist_data.Draw("e0")
bkg_only_graph.Draw("c, same")
sig_only_graph.Draw("c, same")
model_graph.Draw("c, same")

leg.Draw("same")
c.SaveAs("bump-hunt.png")
# Out:
# Info in <TCanvas::Print>: png file bump-hunt.png has been created
